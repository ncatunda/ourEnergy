# %% [markdown]
# # Weather file error

# %%
import pandas as pd

error = pd.read_csv("error_weatherfiles.csv", header=[6]) #Hourly events on analytics
error.head()
# Out:
#    kWh/m2  Wh/m2  Wh/m2.1 ERROR %  ERROR |ERROR| %  |ERROR|   \
# 0     0.0    0.0        0   0.00%    0.0     0.00%       0.0
# 1     0.0    0.0        0   0.00%    0.0     0.00%       0.0
# 2     0.0    0.0        0   0.00%    0.0     0.00%       0.0
# 3     0.0    0.0        0   0.00%    0.0     0.00%       0.0
# 4     0.0    0.0        0   0.00%    0.0     0.00%       0.0
#
#    Normal Distribution  kWh/m2.1  Wh/m2.2  Wh/m2.3 ERROR %.1  ERROR.1  \
# 0                 0.11       0.0      0.0      0.0     0.00%      0.0
# 1                 0.11       0.0      0.0      0.0     0.00%      0.0
# 2                 0.11       0.0      0.0      0.0     0.00%      0.0
# 3                 0.11       0.0      0.0      0.0     0.00%      0.0
# 4                 0.11       0.0      0.0      0.0     0.00%      0.0
#
#   |ERROR| %.1  |ERROR| .1  Normal distribution
# 0        0.0%         0.0                 0.07
# 1        0.0%         0.0                 0.07
# ...

# %% [markdown]
# ## Historical weather file - error %

# %%
x = occdet[['Temperature','Humidity','Light','CO2','HumidityRatio']] # fetching only inputs
x.head()
